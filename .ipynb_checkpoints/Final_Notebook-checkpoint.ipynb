# %%
# Final Notebook containing all Machine Learning Models on https://stbere.github.io/project-4/ in
# the order that they appear:

# %%
# First ML Model

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load the CSV file into a Pandas DataFrame
df = pd.read_csv('./resources/fhfagov-2021.csv')

# %%
# Choose the target variable and independent variables
target_var = 'NoteAmount'
ind_vars = ['TotalMonthlyIncomeAmount', 'LTVRatioPercent']

# %%
# Split the data into training and testing sets
train_size = 0.8
train_idx = int(train_size * len(df))
train_data = df.iloc[:train_idx]
test_data = df.iloc[train_idx:]

# %%
# Fit a linear regression model to the training data
model = LinearRegression()
model.fit(train_data[ind_vars], train_data[target_var])
# Out:
# LinearRegression()

# %%
# Ignore the warning message resulting from making a prediction on the test data
pd.options.mode.chained_assignment = None

# %%
# Make predictions on the test data
test_data['predictions'] = model.predict(test_data[ind_vars])

# %%
# Plot the results
plt.scatter(test_data[target_var], test_data['predictions'])
plt.xlabel('Actual Loan Amount')
plt.ylabel('Predicted Loan Amount')
plt.title('Linear Regression Model')
plt.show()

# %%
# Save to images folder
fig = plt.figure()
fig.savefig('../images/fhfa-ml_linear.regression.png')

# %%
# Second ML Model

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
from io import StringIO
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# I had to create a workaround to use my CSV files uploaded to Google Drive
url = 'https://drive.google.com/file/d/1beJ4WIuq1oFtW78v4zeszPCuX1oyDxJf/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
print(df.head())

# file_path = '../resources/zillowhomevalues_tulsacounty.csv'
# df = pd.read_csv(file_path)
# print(df.head())
# Out:
#    RegionID  SizeRank    RegionName RegionType StateName State      Metro  \
# 0     20859        50         Tulsa       city        OK    OK  Tulsa, OK
# 1     37596       319  Broken Arrow       city        OK    OK  Tulsa, OK
# 2     10834      1176     Claremore       city        OK    OK  Tulsa, OK
# 3     40207      1334        Owasso       city        OK    OK  Tulsa, OK
# 4     16899      1395  Bartlesville       city        OK    OK  Tulsa, OK
#
#        CountyName     1/31/2000     2/29/2000  ...    5/31/2022    6/30/2022  \
# 0    Tulsa County   75173.10114   74895.19799  ...  173162.1185  175038.8721
# 1  Wagoner County  119608.60330  119273.43180  ...  243725.7268  246873.2242
# 2   Rogers County   98698.46066   98857.94421  ...  223035.0960  225944.4216
# 3    Tulsa County  136821.99770  136548.01090  ...  270843.0323  274227.0604
# 4    Osage County   60386.76441   60445.58413  ...  147570.7028  149264.4522
#
#      7/31/2022    8/31/2022    9/30/2022   10/31/2022   11/30/2022  \
# 0  176847.6637  177963.3019  178553.3453  179207.4421  180206.1911
# 1  249450.6218  250904.2633  251292.1894  251634.9022  252216.2665
# 2  228056.4520  229576.6536  230390.9509  230778.2060  231100.5736
# 3  276812.7433  278480.9101  279326.7689  279967.8909  280661.7128
# 4  150534.3586  151138.9929  151390.6966  151960.5016  152916.3293
#
#     12/31/2022    1/31/2023    2/28/2023
# 0  180686.2336  181426.9355  182100.7298
# 1  252626.8944  252856.4406  253154.8957
# 2  230989.2206  230569.8770  231057.3539
# 3  281143.2171  281059.5819  280984.9970
# 4  153867.5800  154727.5249  155654.0228
#
# [5 rows x 286 columns]

# %%
print(df.head())
print(df.columns)
# Out:
#    RegionID  SizeRank    RegionName RegionType StateName State      Metro  \
# 0     20859        50         Tulsa       city        OK    OK  Tulsa, OK
# 1     37596       319  Broken Arrow       city        OK    OK  Tulsa, OK
# 2     10834      1176     Claremore       city        OK    OK  Tulsa, OK
# 3     40207      1334        Owasso       city        OK    OK  Tulsa, OK
# 4     16899      1395  Bartlesville       city        OK    OK  Tulsa, OK
#
#        CountyName     1/31/2000     2/29/2000  ...    5/31/2022    6/30/2022  \
# 0    Tulsa County   75173.10114   74895.19799  ...  173162.1185  175038.8721
# 1  Wagoner County  119608.60330  119273.43180  ...  243725.7268  246873.2242
# 2   Rogers County   98698.46066   98857.94421  ...  223035.0960  225944.4216
# 3    Tulsa County  136821.99770  136548.01090  ...  270843.0323  274227.0604
# 4    Osage County   60386.76441   60445.58413  ...  147570.7028  149264.4522
#
#      7/31/2022    8/31/2022    9/30/2022   10/31/2022   11/30/2022  \
# 0  176847.6637  177963.3019  178553.3453  179207.4421  180206.1911
# 1  249450.6218  250904.2633  251292.1894  251634.9022  252216.2665
# 2  228056.4520  229576.6536  230390.9509  230778.2060  231100.5736
# 3  276812.7433  278480.9101  279326.7689  279967.8909  280661.7128
# 4  150534.3586  151138.9929  151390.6966  151960.5016  152916.3293
#
#     12/31/2022    1/31/2023    2/28/2023
# 0  180686.2336  181426.9355  182100.7298
# 1  252626.8944  252856.4406  253154.8957
# 2  230989.2206  230569.8770  231057.3539
# 3  281143.2171  281059.5819  280984.9970
# 4  153867.5800  154727.5249  155654.0228
#
# [5 rows x 286 columns]
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'CountyName', '1/31/2000', '2/29/2000',
#        ...
#        '5/31/2022', '6/30/2022', '7/31/2022', '8/31/2022', '9/30/2022',
#        '10/31/2022', '11/30/2022', '12/31/2022', '1/31/2023', '2/28/2023'],
#       dtype='object', length=286)

# %%
# Strip whitespaces from column names
df.columns = [col.strip() if isinstance(col, str) else col for col in df.columns]

# Reshape the data
date_columns = df.columns[8:]
reshaped_data = df.melt(id_vars=['RegionName'], value_vars=date_columns, var_name='Date', value_name='AveragePrice')
reshaped_data['Date'] = pd.to_datetime(reshaped_data['Date'])

# %%
# Calculate the number of months since the starting date (1/31/2000)
reshaped_data['MonthsSinceStart'] = (reshaped_data['Date'] - pd.to_datetime('2000-01-31')).dt.days // 30

# %%
# Fill missing values with the mean of the column
reshaped_data['AveragePrice'].fillna(reshaped_data['AveragePrice'].mean(), inplace=True)

# %%
# Drop rows with NaN values in the 'AveragePrice' column
reshaped_data.dropna(subset=['AveragePrice'], inplace=True)

# %%
# Split the data into training and testing sets
X = reshaped_data[['MonthsSinceStart']]
y = reshaped_data['AveragePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# %%
# Plot the training data and the regression line
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='red', label='Testing data')
plt.plot(X, model.predict(X), color='black', label='Linear regression')
plt.xlabel('Months Since Start')
plt.ylabel('Average Home Price')
plt.legend()

# Save the plot to a PNG file
plt.savefig('../images/zillowdata-tulsaCo_regressionplot.png', dpi=300)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
# Calculate the evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")

# %%
import requests

url = "https://realtor16.p.rapidapi.com/forsale"

querystring = {"location":"Tulsa, OK","type":"single_family,condos"}

headers = {
    "X-RapidAPI-Key": "76490fed8emsh572f0cf9756d50bp192dd4jsn630ef9ad03df",
    "X-RapidAPI-Host": "realtor16.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"home_search":{"count":50,"results":[{"branding":[{"name":"Chinowth & Cohen REALTORS","photo":null,"type":"Office"}],"coming_soon_date":null,"community":null,"description":{"baths":3,"baths_1qtr":null,"baths_3qtr":null,"baths_full":2,"baths_half":1,"beds":2,"garage":2,"lot_sqft":12937,"name":null,"sold_date":"2004-04-15","sold_price":446500,"sqft":3772,"stories":2,"sub_type":null,"type":"single_family","year_built":1986},"flags":{"is_coming_soon":null,"is_contingent":null,"is_foreclosure":null,"is_new_construction":null,"is_new_listing":true,"is_pending":null,"is_plan":null,"is_price_reduced":null,"is_subdivision":null},"last_update_date":"2023-04-11T16:26:36Z","lead_attributes":{"lead_type":"co_broke","opcity_lead_attributes":{"cashback_enabled":false,"flip_the_market_enabled":false},"ready_connect_mortgage":{"show_contact_a_lender":true,"show_veterans_united":true},"show_contact_an_agent":true},"list_date":"2023-04-11T21:28:00Z","list_price":1200000,"listing_id":"2954454861","location":{"address":{"city":"Tulsa","coordinate":{"lat":36.135629,"lon":-95.971201},"line":"1509 E 19th St","postal_code":"74120","state":"Oklahoma","state_code":"OK"},"county":{"fips_code":"40143","name":"Tulsa"},"street_view_url":"https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1509%20E%2019th%20St%2C%20Tulsa%2C%20OK%2074120&size=640x480&source=outdoor&signature=pYbeQzRkozOvY2kNlW45AQJFz1E="},"matterport":false,"open_houses":null,"other_listings":{"rdc":[{"listing_id":"2954454861","listing_key":null,"primary":true,"status":"for_sale"},{"listing_id":"579815111","listing_key":null,"primary":null,"status":"off_market"}]},"permalink":"1509-E-19th-St_Tulsa_OK_74120_M88372-87673","photos":[{"href":"https://ap.rdcpix.com/117d654a38892054099b3b4f092aabf1l-m917250209s.jpg"},{"href":"https://ap.rdcpix.com/117d654a38892054099b3b4f092aabf1l-m1331542983s.jpg"}],"price_reduced_amount":null,"primary_photo":{"href":"https://ap.rdcpix.com/117d654a38892054099b3b4f092aabf1l-m917250209s.jpg"},"products":{"brand_name":"essentials","products":["core.agent","core.broker","co_broke"]},"property_id":"8837287673","source":{"agents":[{"office_name":null}],"id":"TUOK","plan_id":null,"spec_id":null,"type":"mls"},"status":"for_sale","tags":["central_air","central_heat","community_outdoor_space","community_security_features","cul_de_sac","dining_room","dishwasher","fireplace","hardwood_floors","washer_dryer","two_or_more_stories","garage_1_or_more","garage_2_or_more","library","playground","lake","medicalcare"],"tax_record":{"public_record_id":"8B4EEE19AD7CCD297256CEED6C9C6BFB"},"virtual_tours":null},{"branding":[{"name":"McGraw REALTORS\u00ae - Midtown Tulsa","photo":null,"type":"Office"}],"coming_soon_date":null,"community":null,"description":{"baths":1,"baths_1qtr":null,"baths_3qtr":null,"baths_full":1,"baths_half":null,"beds":3,"garage":1,"lot_sqft":7754,"name":null,"sold_date":"2005-03-17","sold_price":61500,"sqft":884,"stories":1,"sub_type":null,"type":"single_family","year_built":1967},"flags":{"is_coming_soon":null,"is_contingent":null,"is_foreclosure":null,"is_new_construction":null,"is_new_listing":true,"is_pending":null,"is_plan":null,"is_price_reduced":null,"is_subdivision":null},"last_update_date":"2023-04-11T15:58:32Z","lead_attributes":{"lead_type":"co_broke","opcity_lead_attributes":{"cashback_enabled":false,"flip_the_market_enabled":false},"ready_connect_mortgage":{"show_contact_a_lender":true,"show_veterans_united":true},"show_contact_an_agent":true},"list_date":"2023-04-11T21:01:34Z","list_price":119000,"listing_id":"2954453700","location":{"address":{"city":"Tulsa","coordinate":{"lat":36.135912,"lon":-95.833635},"line":"1843 S 128th East Ave","postal_code":"74128","state":"Oklahoma","state_code":"OK"},"county":{"fips_code":"40143","name":"Tulsa"},"street_view_url":"https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1843%20S%20128th%20East%20Ave%2C%20Tul ...

# %%
import pandas as pd
import requests
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
import json
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
# Define the API parameters
url = "https://realtor16.p.rapidapi.com/forsale"
querystring = {"location": "Tulsa, OK", "type": "single_family"}

# %%
# Define the API headers
headers = {
    "X-RapidAPI-Key": "76490fed8emsh572f0cf9756d50bp192dd4jsn630ef9ad03df",
    "X-RapidAPI-Host": "realtor16.p.rapidapi.com",
}

# %%
# Send the API request and get the response
response = requests.get(url, headers=headers, params=querystring)
data = response.json()

# %%
# Extract the relevant data from the response
response_data = json.loads(response.text)
df = pd.DataFrame(response_data["home_search"]["results"])
df = df[["list_price", "description"]]
df["beds"] = df["description"].apply(lambda x: x["beds"])
df["baths"] = df["description"].apply(lambda x: x["baths_full"])
df["sqft"] = df["description"].apply(lambda x: x["sqft"])
df["year_built"] = df["description"].apply(lambda x: x["year_built"])
df = df[["list_price", "beds", "baths", "sqft", "year_built"]]
df.columns = ["price", "beds", "baths_full", "sqft", "year_built"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21808\571487194.py in <module>
#       1 # Extract the relevant data from the response
#       2 response_data = json.loads(response.text)
# ----> 3 df = pd.DataFrame(response_data["home_search"]["results"])
#       4 df = df[["list_price", "description"]]
#       5 df["beds"] = df["description"].apply(lambda x: x["beds"])
#
# KeyError: 'home_search'

# %%
print(df.shape[0])
# Out:
# 50

# %%
# Preprocess the data
df = df.dropna()
X = df.drop("price", axis=1)
y = df["price"]
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Add quadratic features
poly = PolynomialFeatures(degree=1)
X_poly = poly.fit_transform(X)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)

# %%
# Train a linear regression model on the training data
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluate the model on the testing data
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("MAE:", mae)
print("R^2:", r2)
# Out:
# MAE: 205430.9966475232
# R^2: 0.3592968194463324

# %%
pd.plotting.scatter_matrix(df, figsize=(10, 10))
plt.show()

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

x = df['beds']
y = df['baths_full']
z = df['price']

ax.scatter(x, y, z)

ax.set_xlabel('Bedrooms')
ax.set_ylabel('Bathrooms')
ax.set_zlabel('Price')

plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>
