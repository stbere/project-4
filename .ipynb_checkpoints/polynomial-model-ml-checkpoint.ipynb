# %%
import requests

url = "https://realtor16.p.rapidapi.com/forsale"

querystring = {"location":"Tulsa, OK","type":"single_family,condos"}

headers = {
    "X-RapidAPI-Key": "",
    "X-RapidAPI-Host": "realtor16.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"home_search":{"count":50,"results":[{"branding":[{"name":"eXp Realty","photo":null,"type":"Office"}],"coming_soon_date":null,"community":null,"description":{"baths":2,"baths_1qtr":null,"baths_3qtr":null,"baths_full":1,"baths_half":1,"beds":3,"garage":2,"lot_sqft":7667,"name":null,"sold_date":null,"sold_price":null,"sqft":1453,"stories":1,"sub_type":null,"type":"single_family","year_built":1955},"flags":{"is_coming_soon":null,"is_contingent":null,"is_foreclosure":null,"is_new_construction":null,"is_new_listing":true,"is_pending":null,"is_plan":null,"is_price_reduced":null,"is_subdivision":null},"last_update_date":"2023-04-10T17:00:48Z","lead_attributes":{"lead_type":"co_broke","opcity_lead_attributes":{"cashback_enabled":false,"flip_the_market_enabled":false},"ready_connect_mortgage":{"show_contact_a_lender":true,"show_veterans_united":true},"show_contact_an_agent":true},"list_date":"2023-04-10T22:06:37Z","list_price":206000,"listing_id":"2954419225","location":{"address":{"city":"Tulsa","coordinate":{"lat":36.128055,"lon":-95.906771},"line":"5954 E 24th Pl","postal_code":"74114","state":"Oklahoma","state_code":"OK"},"county":{"fips_code":"40143","name":"Tulsa"},"street_view_url":"https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5954%20E%2024th%20Pl%2C%20Tulsa%2C%20OK%2074114&size=640x480&source=outdoor&signature=BZk4Wf-RkG3xrI25OiLEexlETTc="},"matterport":false,"open_houses":null,"other_listings":{"rdc":[{"listing_id":"2954419225","listing_key":null,"primary":true,"status":"for_sale"}]},"permalink":"5954-E-24th-Pl_Tulsa_OK_74114_M86317-77372","photos":[{"href":"https://ap.rdcpix.com/47c3838dec44204d6d57cf10543ede8al-m2428249846s.jpg"},{"href":"https://ap.rdcpix.com/47c3838dec44204d6d57cf10543ede8al-m1049584788s.jpg"}],"price_reduced_amount":null,"primary_photo":{"href":"https://ap.rdcpix.com/47c3838dec44204d6d57cf10543ede8al-m2428249846s.jpg"},"products":{"brand_name":"essentials","products":["core.agent","core.broker","co_broke"]},"property_id":"8631777372","source":{"agents":[{"office_name":null}],"id":"TUOK","plan_id":null,"spec_id":null,"type":"mls"},"status":"for_sale","tags":["central_air","central_heat","community_outdoor_space","den_or_office","dishwasher","hardwood_floors","washer_dryer","single_story","garage_1_or_more","garage_2_or_more","community_swimming_pool","basketball_court","big_yard","fenced_yard","private_bathroom","master_bedroom","tennis_court","tennis","basketball","shopping"],"tax_record":{"public_record_id":"1F00650987D58AAA64FAE27B36083FAB"},"virtual_tours":null},{"branding":[{"name":"McGraw REALTORS\u00ae - Midtown Tulsa","photo":null,"type":"Office"}],"coming_soon_date":null,"community":null,"description":{"baths":2,"baths_1qtr":null,"baths_3qtr":null,"baths_full":2,"baths_half":null,"beds":3,"garage":2,"lot_sqft":17163,"name":null,"sold_date":null,"sold_price":null,"sqft":2374,"stories":1,"sub_type":null,"type":"single_family","year_built":1980},"flags":{"is_coming_soon":null,"is_contingent":null,"is_foreclosure":null,"is_new_construction":null,"is_new_listing":true,"is_pending":null,"is_plan":null,"is_price_reduced":null,"is_subdivision":null},"last_update_date":"2023-04-10T15:56:05Z","lead_attributes":{"lead_type":"co_broke","opcity_lead_attributes":{"cashback_enabled":false,"flip_the_market_enabled":false},"ready_connect_mortgage":{"show_contact_a_lender":true,"show_veterans_united":true},"show_contact_an_agent":true},"list_date":"2023-04-10T20:57:29Z","list_price":315000,"listing_id":"2954416066","location":{"address":{"city":"Tulsa","coordinate":{"lat":36.057499,"lon":-95.953519},"line":"7310 S Birmingham Ave","postal_code":"74136","state":"Oklahoma","state_code":"OK"},"county":{"fips_code":"40143","name":"Tulsa"},"street_view_url":"https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=7310%20S%20Birmingham%20Ave%2C%20Tulsa%2C%20OK%2074136&size=640x480&source=outdoor&signature=2MgZTmkrog ...

# %%
import pandas as pd
import requests
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
import json
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
# Define the API parameters
url = "https://realtor16.p.rapidapi.com/forsale"
querystring = {"location": "Tulsa, OK", "type": "single_family"}

# %%
# Define the API headers
headers = {
    "X-RapidAPI-Key": "76490fed8emsh572f0cf9756d50bp192dd4jsn630ef9ad03df",
    "X-RapidAPI-Host": "realtor16.p.rapidapi.com",
}

# %%
# Send the API request and get the response
response = requests.get(url, headers=headers, params=querystring)
data = response.json()

# %%
print(df.head())
# Out:
#                                             branding coming_soon_date  \
# 0  [{'name': 'eXp Realty', 'photo': None, 'type':...             None
# 1  [{'name': 'McGraw REALTORS® - Midtown Tulsa', ...             None
# 2  [{'name': 'Chinowth & Cohen REALTORS', 'photo'...             None
# 3  [{'name': 'McGraw REALTORS® - South Memorial T...             None
# 4  [{'name': 'Keller Williams Advantage', 'photo'...             None
#
#   community                                        description  \
# 0      None  {'baths': 2, 'baths_1qtr': None, 'baths_3qtr':...
# 1      None  {'baths': 2, 'baths_1qtr': None, 'baths_3qtr':...
# 2      None  {'baths': 2, 'baths_1qtr': None, 'baths_3qtr':...
# 3      None  {'baths': 10, 'baths_1qtr': None, 'baths_3qtr'...
# 4      None  {'baths': 5, 'baths_1qtr': None, 'baths_3qtr':...
#
#                                                flags      last_update_date  \
# 0  {'is_coming_soon': None, 'is_contingent': None...  2023-04-10T17:00:48Z
# 1  {'is_coming_soon': None, 'is_contingent': None...  2023-04-10T15:56:05Z
# 2  {'is_coming_soon': None, 'is_contingent': None...  2023-04-10T14:19:42Z
# 3  {'is_coming_soon': None, 'is_contingent': None...  2023-04-10T13:40:26Z
# 4  {'is_coming_soon': None, 'is_contingent': None...  2023-04-10T15:39:26Z
#
#                                      lead_attributes             list_date  \
# 0  {'lead_type': 'co_broke', 'opcity_lead_attribu...  2023-04-10T22:06:37Z
# 1  {'lead_type': 'co_broke', 'opcity_lead_attribu...  2023-04-10T20:57:29Z
# 2  {'lead_type': 'co_broke', 'opcity_lead_attribu...  2023-04-10T19:22:21Z
# 3  {'lead_type': 'co_broke', 'opcity_lead_attribu...  2023-04-10T18:42:51Z
# 4  {'lead_type': 'co_broke', 'opcity_lead_attribu...  2023-04-10T18:24:57Z
#
#    list_price  listing_id  ...  \
# 0      206000  2954419225  ...
# 1      315000  2954416066  ...
# 2      230000  2954412488  ...
# 3     8500000  2954410723  ...
# 4      749900  2954410106  ...
#
#                                               photos  price_reduced_amount  \
# 0  [{'href': 'https://ap.rdcpix.com/47c3838dec442...                  None
# 1  [{'href': 'https://ap.rdcpix.com/fd0f55beb0cf7...                  None
# 2  [{'href': 'https://ap.rdcpix.com/a650f688f6f08...                  None
# 3  [{'href': 'https://ap.rdcpix.com/1619db5b4afe9...                  None
# 4  [{'href': 'https://ap.rdcpix.com/e3292bbba21d1...                  None
#
#                                        primary_photo  \
# 0  {'href': 'https://ap.rdcpix.com/47c3838dec4420...
# 1  {'href': 'https://ap.rdcpix.com/fd0f55beb0cf72...
# 2  {'href': 'https://ap.rdcpix.com/a650f688f6f08a...
# 3  {'href': 'https://ap.rdcpix.com/1619db5b4afe9a...
# 4  {'href': 'https://ap.rdcpix.com/e3292bbba21d19...
#
#                                             products property_id  \
# 0  {'brand_name': 'essentials', 'products': ['cor...  8631777372
# 1  {'brand_name': 'essentials', 'products': ['cor...  7478849941
# 2  {'brand_name': 'essentials', 'products': ['cor...  8643461208
# 3  {'brand_name': 'essentials', 'products': ['cor...  7136323622
# 4  {'brand_name': 'basic_opt_in', 'products': ['c...  8546368906
#
#                                               source    status  \
# 0  {'agents': [{'office_name': None}], 'id': 'TUO...  for_sale
# 1  {'agents': [{'office_name': None}], 'id': 'TUO...  for_sale
# 2  {'agents': [{'office_name': 'Chinowth & Cohen'...  for_sale
# 3  {'agents': [{'office_name': None}], 'id': 'TUO...  for_sale
# 4  {'agents': [{'office_name': 'Be Living Enterpr...  for_sale
#
#                                                 tags  \
# 0  [central_air, central_heat, community_outdoor_...
# 1  [central_air, central_heat, community_outdoor_...
# 2  [central_air, central_heat, dishwasher, firepl...
# 3  [central_air, central_heat, community_outdoor_...
# 4  [central_air, central_heat, community_clubhous...
#
#                                           tax_record virtual_tours
# 0  {'public_record_id': '1F00650987D58AAA64FAE27B...          None
# 1  {'public_record_id': 'CAB6F8CE3D0AC53B2E8EEE89...          None
# 2  {'public_record_id': '85FB904176E79258B7FAA4FA...          None
# 3  {'public_record_id': '05470F27F1A4D84610CFEF18...          None
# 4  {'public_record_id': '2F76AFA4F84D975CBA795341...          None
#
# [5 rows x 25 columns]

# %%
# Extract the relevant data from the response
response_data = json.loads(response.text)
df = pd.DataFrame(response_data["home_search"]["results"])
df = df[["list_price", "description"]]
df["beds"] = df["description"].apply(lambda x: x["beds"])
df["baths"] = df["description"].apply(lambda x: x["baths_full"])
df["sqft"] = df["description"].apply(lambda x: x["sqft"])
df["year_built"] = df["description"].apply(lambda x: x["year_built"])
df = df[["list_price", "beds", "baths", "sqft", "year_built"]]
df.columns = ["price", "beds", "baths_full", "sqft", "year_built"]

# %%
print(df.shape[0])
# Out:
# 49

# %%
# Preprocess the data
df = df.dropna()
X = df.drop("price", axis=1)
y = df["price"]
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Add quadratic features
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)

# %%
# Train a linear regression model on the training data
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluate the model on the testing data
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("MAE:", mae)
print("R^2:", r2)
# Out:
# MAE: 128434.28411468216
# R^2: 0.7615992321164494

# %%
pd.plotting.scatter_matrix(df, figsize=(10, 10))
plt.show()

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

x = df['beds']
y = df['baths_full']
z = df['price']

ax.scatter(x, y, z)

ax.set_xlabel('Bedrooms')
ax.set_ylabel('Bathrooms')
ax.set_zlabel('Price')

plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>
